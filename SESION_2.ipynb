# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Darle click para abrir/ocultar los códigos."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Darle click para abrir/ocultar los códigos."></form>

# %% [markdown]
# # Ejemplo 2 : Hurto de motocicletas

# %% [markdown]
# <img src = 'figuras/HURTO_MOTOS.jpg' height=500 width=500>

# %%
import pandas as pd

# %%
Datos_2=pd.read_csv("DATOS/Delito_Hurto_Motocicletas.csv",encoding = 'utf8')

# %%
Datos_2.head()
# Out:
#                     FECHA DEPARTAMENTO    MUNICIPIO     DIA   HORA  \
# 0  01/01/2015 12:00:00 AM     ANTIOQUIA      CAREPA  Jueves   7:30
# 1  01/01/2015 12:00:00 AM     ANTIOQUIA  COPACABANA  Jueves  14:45
# 2  01/01/2015 12:00:00 AM     ANTIOQUIA    EL BAGRE  Jueves   4:00
# 3  01/01/2015 12:00:00 AM     ANTIOQUIA   MARINILLA  Jueves   0:00
# 4  01/01/2015 12:00:00 AM     ANTIOQUIA      RETIRO  Jueves   3:00
#
#          BARRIO    ZONA         CLASE SITIO  EDAD     GENERO  ...  \
# 0  PUEBLO NUEVO  URBANA       VIAS PUBLICAS  26.0  MASCULINO  ...
# 1  VDA. CABUYAL  URBANA       VIAS PUBLICAS  22.0  MASCULINO  ...
# 2         BIJAO  URBANA       VIAS PUBLICAS  29.0   FEMENINO  ...
# 3        CENTRO  URBANA       VIAS PUBLICAS  26.0   FEMENINO  ...
# 4    CARRIZALES   RURAL  FINCAS Y SIMILARES  61.0  MASCULINO  ...
#
#            MOVIL VICTIMA  MARCA   MODELO    LINEA   COLOR ESTADO CIVIL  \
# 0                  A PIE  YAMAHA  2012.0     FZ16   NEGRO  UNION LIBRE
# ...

# %%
Datos_2.shape
# Out:
# (27223, 22)

# %%
Datos_2.dtypes
# Out:
# FECHA             object
# DEPARTAMENTO      object
# MUNICIPIO         object
# DIA               object
# HORA              object
# BARRIO            object
# ZONA              object
# CLASE SITIO       object
# EDAD             float64
# GENERO            object
# ARMA EMPLEADA     object
# MOVIL AGRESOR     object
# MOVIL VICTIMA     object
# MARCA             object
# MODELO           float64
# LINEA             object
# COLOR             object
# ESTADO CIVIL      object
# PROFESIONES       object
# ESCOLARIDAD       object
# CODIGO DANE      float64
# 2015             float64
# dtype: object

# %%
Datos_2.describe(include="all")
# Out:
#                          FECHA DEPARTAMENTO       MUNICIPIO        DIA   HORA  \
# count                    11112         27131          27131      27131  27131
# unique                     236            32            610          7    782
# top     09/02/2015 12:00:00 AM     ANTIOQUIA  MEDELLÍN (CT)  Miércoles  20:00
# freq                       105          6107           4374       4143   1025
# mean                       NaN           NaN            NaN        NaN    NaN
# std                        NaN           NaN            NaN        NaN    NaN
# min                        NaN           NaN            NaN        NaN    NaN
# 25%                        NaN           NaN            NaN        NaN    NaN
# 50%                        NaN           NaN            NaN        NaN    NaN
# 75%                        NaN           NaN            NaN        NaN    NaN
# max                        NaN           NaN            NaN        NaN    NaN
#
# ...

# %%
Datos_2.columns
# Out:
# Index(['FECHA', 'DEPARTAMENTO ', 'MUNICIPIO', 'DIA', 'HORA', 'BARRIO', 'ZONA',
#        'CLASE SITIO', 'EDAD', 'GENERO', 'ARMA EMPLEADA', 'MOVIL AGRESOR',
#        'MOVIL VICTIMA', 'MARCA ', 'MODELO', 'LINEA', 'COLOR', 'ESTADO CIVIL',
#        'PROFESIONES', 'ESCOLARIDAD', 'CODIGO DANE', '2015'],
#       dtype='object')

# %%
Datos_2.rename(columns={'DEPARTAMENTO ':'DEPARTAMENTO'}, inplace=True)

# %%
Datos_2.columns
# Out:
# Index(['FECHA', 'DEPARTAMENTO', 'MUNICIPIO', 'DIA', 'HORA', 'BARRIO', 'ZONA',
#        'CLASE SITIO', 'EDAD', 'GENERO', 'ARMA EMPLEADA', 'MOVIL AGRESOR',
#        'MOVIL VICTIMA', 'MARCA ', 'MODELO', 'LINEA', 'COLOR', 'ESTADO CIVIL',
#        'PROFESIONES', 'ESCOLARIDAD', 'CODIGO DANE', '2015'],
#       dtype='object')

# %%
Datos_2.DEPARTAMENTO.describe()
# Out:
# count         27131
# unique           32
# top       ANTIOQUIA
# freq           6107
# Name: DEPARTAMENTO, dtype: object

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10,6),dpi=80)
plot = Datos_2.DEPARTAMENTO.value_counts().plot(kind='bar',title='DEPARTAMENTO')

# %%
plt.figure(figsize=(10,6),dpi=80)
plot = Datos_2.MUNICIPIO.value_counts().plot(kind='bar',title='MUNICIPIO')

# %%
plt.figure(figsize=(10,6),dpi=80)
VAL_MUN=Datos_2.MUNICIPIO.value_counts()
plot = VAL_MUN[VAL_MUN>100].plot(kind='bar',title='MUNICIPIO')

# %%
plt.figure(figsize=(10,6),dpi=80)
plot = Datos_2.GENERO.value_counts().plot(kind='bar',title='Generación')

# %%
plt.figure(figsize=(10,6),dpi=80)
plot = Datos_2['ESTADO CIVIL'].value_counts().plot(kind='bar',title='Generación')
